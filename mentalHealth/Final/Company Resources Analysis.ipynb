# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# change path name here

data = pd.read_csv("Data/combined.csv")

# %%
# exploring the dataset

unique_questions = data['questiontext'].unique()
# for n in range(len(unique_questions)):
#     print(n, ": ", unique_questions[n])

# see dataset_notes.txt for notes on questions

# %% [markdown]
# # Overview Graphs, of Questions and Answers

# %%
# Graph for Overview of Company's Actions: Overall

# data frame for 10 :  Does your employer provide mental health benefits as part of healthcare coverage?
actions_q10 = data[data['QuestionID'] == 10]
x_values_q10_ = actions_q10[actions_q10['AnswerText'] != '-1']['AnswerText']
print(x_values_q10_.unique())
y_values_q10 = [x_values_q10_.value_counts().get('No', 0), \
                x_values_q10_.value_counts().get('Yes', 0), \
                x_values_q10_.value_counts().get('Don\'t know', 0),    
                x_values_q10_.value_counts().get('Not eligible for coverage / NA', 0)]
x_values_q10 = ['No', 'Yes', 'Don\'t Know', 'Not eligible \nfor coverage / NA']

print(y_values_q10)

plt.bar(x_values_q10, y_values_q10, color='blue')
plt.xlabel('Does your employer provide mental health benefits \nas part of healthcare coverage?')
plt.ylabel('Frequency')
plt.show()
# Out:
# ['Yes' "Don't know" 'No' 'Not eligible for coverage / NA' "I don't know"]
# [756, 1744, 408, 148]

# %%
# Graph for Overview of Company's Actions

# data frame for 94 :  Do you know the options for mental health care your employer provides?
actions_q94 = data[data['QuestionID'] == 94]
x_values_q94_ = actions_q94[actions_q94['AnswerText'] != '-1']['AnswerText']
print(x_values_q94_.unique())
y_values_q94 = [x_values_q94_.value_counts().get('No', 0), x_values_q94_.value_counts().get('Yes', 0), x_values_q94_.value_counts().get('Not sure', 0)]
x_values_q94 = ['No', 'Yes', 'Don\'t Know']

# data frame for 14 :  Do you know the options for mental health care available under your employer-provided health coverage?
actions_q14 = data[data['QuestionID'] == 14]
x_values_q14_ = actions_q14[actions_q14['AnswerText'] != '-1']['AnswerText']
print(x_values_q14_.unique())
y_values_q14 = [x_values_q14_.value_counts().get('No', 0), \
                x_values_q14_.value_counts().get('Yes, always', 0), \
                    x_values_q14_.value_counts().get('I am not sure', 0)]
x_values_q14 = ['No', 'Yes', 'Don\'t know']

y_values_q94_q14 = [y_values_q94[0] + y_values_q14[0],\
                    y_values_q94[1] + y_values_q14[1],\
                    y_values_q94[2] + y_values_q14[2]]
print(y_values_q94_q14)
x_values_q94_q14 = ['No', 'Yes', 'Don\'t know']

# plt.bar(x_values_q16, y_values_q16, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# plt.bar(x_values_q27, y_values_q27, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# Combined Plot for Question 16 nad Question 27
plt.bar(x_values_q94_q14, y_values_q94_q14, color='blue')
plt.xlabel('Do you know the options for mental health care your employer provides?')
plt.ylabel('Frequency')
plt.show()
# Out:
# ['Not sure' 'No' 'Yes']
# ['Yes' 'I am not sure' 'No']
# [1472, 444, 666]

# %%
# Graph for Overview of Company's Actions

# data frame for 95 :  Has your employer ever discussed mental health as part of an employee wellness program?
actions_q95 = data[data['QuestionID'] == 95]
x_values_q95_ = actions_q95[actions_q95['AnswerText'] != '-1']['AnswerText']
print(x_values_q95_.unique())
y_values_q95 = [x_values_q95_.value_counts().get('No', 0), x_values_q95_.value_counts().get('Yes', 0), x_values_q95_.value_counts().get('Don\'t Know', 0)]
x_values_q95 = ['No', 'Yes', 'Don\'t Know']

# data frame for 15 :  Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?
actions_q15 = data[data['QuestionID'] == 15]
x_values_q15_ = actions_q15[actions_q15['AnswerText'] != '-1']['AnswerText']
print(x_values_q15_.unique())
y_values_q15 = [x_values_q15_.value_counts().get('No', 0), \
                x_values_q15_.value_counts().get('Yes', 0), \
                    x_values_q15_.value_counts().get('Don\'t know', 0)]
x_values_q15 = ['No', 'Yes', 'Don\'t know']

y_values_q95_q15 = [y_values_q95[0] + y_values_q15[0],\
                    y_values_q95[1] + y_values_q15[1],\
                    y_values_q95[2] + y_values_q15[2]]
print(y_values_q95_q15)
x_values_q95_q15 = ['No', 'Yes', 'Don\'t know']

# plt.bar(x_values_q16, y_values_q16, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# plt.bar(x_values_q27, y_values_q27, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# Combined Plot for Question 16 nad Question 27
plt.bar(x_values_q95_q15, y_values_q95_q15, color='blue')
plt.xlabel('Has your employer ever discussed mental health \nas part of an employee wellness program?')
plt.ylabel('Frequency')
plt.show()
# Out:
# ['No' "Don't know" 'Yes']
# ['No' 'Yes' "I don't know"]
# [2469, 828, 0]

# %%
# Graph for Overview of Company's Actions

# data frame for 96 :  Does your employer provide resources to learn more about mental health issues and how to seek help?
actions_q96 = data[data['QuestionID'] == 96]
x_values_q96_ = actions_q96[actions_q96['AnswerText'] != '-1']['AnswerText']
print(x_values_q96_.unique())
y_values_q96 = [x_values_q96_.value_counts().get('No', 0), x_values_q96_.value_counts().get('Yes', 0), x_values_q96_.value_counts().get('Don\'t Know', 0)]
x_values_q96 = ['No', 'Yes', 'Don\'t Know']

# data frame for 16 :  Does your employer offer resources to learn more about mental health disorders and options for seeking help?
actions_q16 = data[data['QuestionID'] == 16]
x_values_q16_ = actions_q16[actions_q16['AnswerText'] != '-1']['AnswerText']
print(x_values_q16_.unique())
y_values_q16 = [x_values_q16_.value_counts().get('No', 0), \
                x_values_q16_.value_counts().get('Yes', 0), \
                    x_values_q16_.value_counts().get('Don\'t know', 0)]
x_values_q16 = ['No', 'Yes', 'Don\'t know']

y_values_q96_q16 = [y_values_q96[0] + y_values_q16[0],\
                    y_values_q96[1] + y_values_q16[1],\
                    y_values_q96[2] + y_values_q16[2]]
print(y_values_q96_q16)
x_values_q96_q16 = ['No', 'Yes', 'Don\'t know']

# plt.bar(x_values_q16, y_values_q16, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# plt.bar(x_values_q27, y_values_q27, color='blue')
# plt.xlabel('Do you know the options for mental health care your employer provides?')
# plt.ylabel('Frequency')
# plt.show()

# Combined Plot for Question 16 nad Question 27
plt.bar(x_values_q96_q16, y_values_q96_q16, color='blue')
plt.xlabel('Does your employer provide resources to learn more about \nmental health issues and how to seek help?')
plt.ylabel('Frequency')
plt.show()
# Out:
# ['Yes' "Don't know" 'No']
# ['No' 'Yes' "I don't know"]
# [1731, 952, 0]

# %%
# Graph for Overview of Company's Actions

# create data 
df = pd.DataFrame([['Does your employer provide mental health \nbenefits as part of healthcare coverage?', y_values_q10[0], y_values_q10[1], y_values_q10[2]], \
                   ['Do you know the options for mental health \ncare your employer provides?', y_values_q94_q14[0], y_values_q94_q14[1], y_values_q94_q14[2]], \
                    ['Has your employer ever discussed mental health\n as part of an employee wellness program?', y_values_q95_q15[0], y_values_q95_q15[1], y_values_q95_q15[2]], \
                    ['Does your employer provide resources to \nlearn more about mental health issues and how to seek help?', y_values_q96_q16[0], y_values_q96_q16[1], y_values_q96_q16[2]]], \
                  columns=['Questions', 'No', 'Yes', 'Don\'t Know']) 

# view data 
print(df) 

# plot grouped bar chart 
df.plot(x='Questions', 
        kind='barh', 
        stacked=False, 
        title='Overview of Company\'s Actions',  color=['red', 'green', 'grey'])


plt.rcParams['savefig.dpi'] = 300  
plt.savefig('overview.png', dpi=300, bbox_inches='tight')
# Out:
#                                            Questions    No   Yes  Don't Know
# 0  Does your employer provide mental health \nben...   756  1744         408
# 1  Do you know the options for mental health \nca...  1472   444         666
# 2  Has your employer ever discussed mental health...  2469   828           0
# 3  Does your employer provide resources to \nlear...  1731   952           0

# %% [markdown]
# # Discussion of Mental Health Issues Leading to Negative Consequences against Company's Actions

# %%
# Question 98 :  Do you think that discussing a mental health issue with your employer would have negative consequences?
# Question 10 :  Does your employer provide mental health benefits as part of healthcare coverage?

userid_q10 = data[(data['QuestionID'] == 10)]
# userid_q10_no = data[((data['QuestionID'] == 10) & (data['AnswerText'] == 'Yes'))]
# userid_q10_no = data[((data['QuestionID'] == 10) & (data['AnswerText'] == 'Yes'))]
# print(userid_q10)

userid_q98= data[(data['QuestionID'] == 98)]

merged_q10_q98 = pd.merge(userid_q10, userid_q98[['UserID', 'AnswerText']], on='UserID', how='inner', suffixes = ('_q10', '_q98'))

# print(merged_q10_q98)

# Out of those who answered 'Yes' to "Does your employer provide mental health benefits as part of healthcare coverage?", 
# what is the proportion of people who think Do you think that discussing a mental health issue with your employer would have negative consequences?

print("Question 10", merged_q10_q98['AnswerText_q10'].unique())
print("Question 98", merged_q10_q98['AnswerText_q98'].unique())

yes_responses_q10_q98 = merged_q10_q98[merged_q10_q98['AnswerText_q10'] == 'Yes']
yes_responses_q10_q98_y = yes_responses_q10_q98['AnswerText_q98'].value_counts(normalize=True)

no_responses_q10_q98 = merged_q10_q98[merged_q10_q98['AnswerText_q10'] == 'No']
no_responses_q10_q98_y = no_responses_q10_q98['AnswerText_q98'].value_counts(normalize=True)

dknow_responses_q10_q98 = merged_q10_q98[merged_q10_q98['AnswerText_q10'] == 'Don\'t know']
dknow_responses_q10_q98_y = dknow_responses_q10_q98['AnswerText_q98'].value_counts(normalize=True)

color_mapping= {'Yes': 'green', 'No': 'red', 'Maybe': 'blue'}

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first pie chart for AnswerText_y
axes[0].pie(yes_responses_q10_q98_y, labels=yes_responses_q10_q98_y.index, autopct='%1.1f%%', startangle=90, colors=yes_responses_q10_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[0].set_title('"Yes" Responses \nto Provision \nof Mental Health Benefits', fontsize=18)

# Plot the second pie chart for AnswerText_z
axes[1].pie(no_responses_q10_q98_y, labels=no_responses_q10_q98_y.index, autopct='%1.1f%%', startangle=90, colors=no_responses_q10_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[1].set_title('"No" Responses \nto Provision \nof Mental Health Benefits', fontsize=18)

# Plot the first pie chart for AnswerText_y
axes[2].pie(dknow_responses_q10_q98_y, labels=dknow_responses_q10_q98_y.index, autopct='%1.1f%%', startangle=90, colors=dknow_responses_q10_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[2].set_title('"Don\'t Know" Responses \nto Provision \nof Mental Health Benefits', fontsize=18)

fig.suptitle("Opinions on Whether Speaking of their Mental Health Issues would have Negative Consequences\n", fontsize=20)
plt.tight_layout()


plt.rcParams['savefig.dpi'] = 300  
plt.savefig('provision_MRH.png', dpi=300, bbox_inches='tight')
# Out:
# Question 10 ['Yes' "Don't know" 'No']
# Question 98 ['No' 'Maybe' 'Yes']

# %%
# Question 98 :  Do you think that discussing a mental health issue with your employer would have negative consequences?
# ---
# Question 94 :  Do you know the options for mental health care your employer provides?
# Question 14 :  Do you know the options for mental health care available under your employer-provided health coverage?

data_copy = data
condition = data_copy['QuestionID'] == 14
data_copy.loc[condition, 'QuestionID'] = 94
#print(data_copy)

userid_q94 = data[(data['QuestionID'] == 94)]
userid_q98= data[(data['QuestionID'] == 98)]

merged_q94_q14_q98 = pd.merge(userid_q94, userid_q98[['UserID', 'AnswerText']], on='UserID', suffixes=('_q94', '_q98'))
# print(merged_q94_q14_q98)

print("Question 94", merged_q94_q14_q98['AnswerText_q94'].unique())
print("Question 98", merged_q94_q14_q98['AnswerText_q98'].unique())

merged_q94_q14_q98 = merged_q94_q14_q98.dropna(subset=['AnswerText_q94'])
merged_q94_q14_q98 = merged_q94_q14_q98.dropna(subset=['AnswerText_q98'])

yes_responses_q94_q98 = merged_q94_q14_q98[merged_q94_q14_q98['AnswerText_q94'] == 'Yes']
yes_responses_q94_q98_y = yes_responses_q94_q98['AnswerText_q98'].value_counts(normalize=True)

no_responses_q94_q98 = merged_q94_q14_q98[merged_q94_q14_q98['AnswerText_q94'] == 'No']
no_responses_q94_q98_y = no_responses_q94_q98['AnswerText_q98'].value_counts(normalize=True)

dknow_responses_q94_q98 = merged_q94_q14_q98[merged_q94_q14_q98['AnswerText_q94'] == 'Not sure']
dknow_responses_q94_q98_y = dknow_responses_q94_q98['AnswerText_q98'].value_counts(normalize=True)

color_mapping= {'Yes': 'green', 'No': 'red', 'Maybe': 'blue'}

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first pie chart for AnswerText_y
axes[0].pie(yes_responses_q94_q98_y, labels=yes_responses_q94_q98_y.index, autopct='%1.1f%%', startangle=90, colors=yes_responses_q94_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[0].set_title('"Yes" Responses \nto Awareness of Mental Health \nResources', fontsize=18)

# Plot the second pie chart for AnswerText_z
axes[1].pie(no_responses_q94_q98_y, labels=no_responses_q94_q98_y.index, autopct='%1.1f%%', startangle=90, colors=no_responses_q94_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[1].set_title('"No" Responses \nto Awareness of Mental Health \nResources', fontsize=18)

# Plot the first pie chart for AnswerText_y
axes[2].pie(dknow_responses_q94_q98_y, labels=dknow_responses_q94_q98_y.index, autopct='%1.1f%%', startangle=90, colors=dknow_responses_q94_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[2].set_title('"Don\'t Know" Responses \nto Awareness of Mental Health \nResources', fontsize=18)

fig.suptitle("Opinions on Whether Speaking of their Mental Health Issues would have Negative Consequences\n", fontsize=20)
plt.tight_layout()

plt.rcParams['savefig.dpi'] = 300  
plt.savefig('awareness_MRH.png', dpi=300, bbox_inches='tight')
# Out:
# Question 94 ['Not sure' 'No' 'Yes']
# Question 98 ['No' 'Maybe' 'Yes']

# %%
# Question 98 :  Do you think that discussing a mental health issue with your employer would have negative consequences?
# ---
# Question 95 :  Has your employer ever discussed mental health as part of an employee wellness program?
# Question 15 :  Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?

data_copy = data
condition = data_copy['QuestionID'] == 15
data_copy.loc[condition, 'QuestionID'] = 95
#print(data_copy)

userid_q95 = data[(data['QuestionID'] == 95)]
userid_q98= data[(data['QuestionID'] == 98)]

merged_q95_q15_q98 = pd.merge(userid_q95, userid_q98[['UserID', 'AnswerText']], on='UserID', suffixes=('_q95', '_q98'))
# print(merged_q95_q15_q98)

# print(merged_q95_q15_q98['AnswerText_q95'].unique())
# print(merged_q95_q15_q98['AnswerText_q98'].unique())

merged_q95_q15_q98 = merged_q95_q15_q98.dropna(subset=['AnswerText_q95'])
merged_q95_q15_q98 = merged_q95_q15_q98.dropna(subset=['AnswerText_q98'])

# merged_q95_q15_q98.value_counts()

yes_responses_q95_q98 = merged_q95_q15_q98[merged_q95_q15_q98['AnswerText_q95'] == 'Yes']
yes_responses_q95_q98_y = yes_responses_q95_q98['AnswerText_q98'].value_counts(normalize=True)

no_responses_q95_q98 = merged_q95_q15_q98[merged_q95_q15_q98['AnswerText_q95'] == 'No']
no_responses_q95_q98_y = no_responses_q95_q98['AnswerText_q98'].value_counts(normalize=True)

dknow_responses_q95_q98 = merged_q95_q15_q98[merged_q95_q15_q98['AnswerText_q95'] == 'Don\'t know']
dknow_responses_q95_q98_y = dknow_responses_q95_q98['AnswerText_q98'].value_counts(normalize=True)

color_mapping= {'Yes': 'green', 'No': 'red', 'Maybe': 'blue'}

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first pie chart for AnswerText_y
axes[0].pie(yes_responses_q95_q98_y, labels=yes_responses_q95_q98_y.index, autopct='%1.1f%%', startangle=90, colors=yes_responses_q95_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[0].set_title('"Yes" Responses \nto Formal Communication \nof Mental Health', fontsize=18)

# Plot the second pie chart for AnswerText_z
axes[1].pie(no_responses_q95_q98_y, labels=no_responses_q95_q98_y.index, autopct='%1.1f%%', startangle=90, colors=no_responses_q95_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[1].set_title('"No" Responses \nto Formal Communication \nof Mental Health  Resources', fontsize=18)

# Plot the first pie chart for AnswerText_y
axes[2].pie(dknow_responses_q95_q98_y, labels=dknow_responses_q95_q98_y.index, autopct='%1.1f%%', startangle=90, colors=dknow_responses_q95_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[2].set_title('"Don\'t Know" Responses \nto Formal Communication \nof Mental Health Resources', fontsize=18)

fig.suptitle("Opinions on Whether Speaking of their Mental Health Issues would have Negative Consequences\n", fontsize=20)
plt.tight_layout()

plt.rcParams['savefig.dpi'] = 300  
plt.savefig('formalcomm_MRH.png', dpi=300, bbox_inches='tight')

# %%
# Question 98 :  Do you think that discussing a mental health issue with your employer would have negative consequences?
# ---
# Question 96 :  Does your employer provide resources to learn more about mental health issues and how to seek help?
# Question 16 :  Does your employer offer resources to learn more about mental health disorders and options for seeking help?

data_copy = data
condition = data_copy['QuestionID'] == 16
data_copy.loc[condition, 'QuestionID'] = 96
#print(data_copy)

userid_q96 = data[(data['QuestionID'] == 96)]
userid_q98= data[(data['QuestionID'] == 98)]

merged_q96_q16_q98 = pd.merge(userid_q96, userid_q98[['UserID', 'AnswerText']], on='UserID', suffixes=('_q96', '_q98'))
# print(merged_q96_q16_q98)

# print(merged_q96_q16_q98['AnswerText_q96'].unique())
# print(merged_q96_q16_q98['AnswerText_q98'].unique())

merged_q96_q16_q98 = merged_q96_q16_q98.dropna(subset=['AnswerText_q96'])
merged_q96_q16_q98 = merged_q96_q16_q98.dropna(subset=['AnswerText_q98'])

# merged_q96_q16_q98.value_counts()

yes_responses_q96_q98 = merged_q96_q16_q98[merged_q96_q16_q98['AnswerText_q96'] == 'Yes']
yes_responses_q96_q98_y = yes_responses_q96_q98['AnswerText_q98'].value_counts(normalize=True)

no_responses_q96_q98 = merged_q96_q16_q98[merged_q96_q16_q98['AnswerText_q96'] == 'No']
no_responses_q96_q98_y = no_responses_q96_q98['AnswerText_q98'].value_counts(normalize=True)

dknow_responses_q96_q98 = merged_q96_q16_q98[merged_q96_q16_q98['AnswerText_q96'] == 'Don\'t know']
dknow_responses_q96_q98_y = dknow_responses_q96_q98['AnswerText_q98'].value_counts(normalize=True)

color_mapping= {'Yes': 'green', 'No': 'red', 'Maybe': 'blue'}

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first pie chart for AnswerText_y
axes[0].pie(yes_responses_q96_q98_y, labels=yes_responses_q96_q98_y.index, autopct='%1.1f%%', startangle=90, colors=yes_responses_q96_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[0].set_title('"Yes" Responses \nto Availability of Resources \nand Options for Seeking Help', fontsize=18)

# Plot the second pie chart for AnswerText_z
axes[1].pie(no_responses_q96_q98_y, labels=no_responses_q95_q98_y.index, autopct='%1.1f%%', startangle=90, colors=no_responses_q96_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[1].set_title('"No" Responses \nto Availability of Resources \nand Options for Seeking Help', fontsize=18)

# Plot the first pie chart for AnswerText_y
axes[2].pie(dknow_responses_q96_q98_y, labels=dknow_responses_q96_q98_y.index, autopct='%1.1f%%', startangle=90, colors=dknow_responses_q96_q98_y.index.map(color_mapping),textprops={'fontsize': 20})
axes[2].set_title('"Don\'t Know" Responses \nto Availability of Resources \nand Options for Seeking Help', fontsize=18)

fig.suptitle("Opinions on Whether Speaking of their Mental Health Issues would have Negative Consequences\n", fontsize=20)
plt.tight_layout()

plt.rcParams['savefig.dpi'] = 300  
plt.savefig('availability_MRH.png', dpi=300, bbox_inches='tight')
